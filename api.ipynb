# %%
import requests
import pandas as pd

# %%
api_url = 'https://randomuser.me/api/'

# %%
response = requests.get(api_url)

# %%
response.json()['results']
# Out:
# [{'gender': 'male',
#   'name': {'title': 'Mr', 'first': 'Jeremy', 'last': 'Roy'},
#   'location': {'street': {'number': 8297, 'name': 'Grand Marais Ave'},
#    'city': 'St. Antoine',
#    'state': 'Nunavut',
#    'country': 'Canada',
#    'postcode': 'B7V 8Y2',
#    'coordinates': {'latitude': '-66.0606', 'longitude': '-147.9802'},
#    'timezone': {'offset': '+5:30',
#     'description': 'Bombay, Calcutta, Madras, New Delhi'}},
#   'email': 'jeremy.roy@example.com',
#   'login': {'uuid': '7cbd8d99-48fa-4c58-b932-93f5b6bbf212',
#    'username': 'bluedog611',
#    'password': 'mandrake',
#    'salt': 'pG7OXxGp',
#    'md5': '9c86cfb9a0388b425c01d8e12bc05c39',
#    'sha1': '2de36e6a6b40e9b988389d081866dc87996679ac',
#    'sha256': 'b5f6af106725560f66e88006650934210c16d580279bd16d03a70acd7e966d6f'},
#   'dob': {'date': '1955-08-25T02:51:24.372Z', 'age': 70},
#   'registered': {'date': '2022-04-20T09:06:39.249Z', 'age': 3},
#   'phone': 'S37 T91-1181',
#   'cell': 'U09 W46-5916',
# ...

# %%
pd.DataFrame(response.json()['results'])
# Out:
#   gender                                               name  \
# 0   male  {'title': 'Mr', 'first': 'Jeremy', 'last': 'Roy'}
#
#                                             location                   email  \
# 0  {'street': {'number': 8297, 'name': 'Grand Mar...  jeremy.roy@example.com
#
#                                                login  \
# 0  {'uuid': '7cbd8d99-48fa-4c58-b932-93f5b6bbf212...
#
#                                                dob  \
# 0  {'date': '1955-08-25T02:51:24.372Z', 'age': 70}
#
#                                        registered         phone          cell  \
# 0  {'date': '2022-04-20T09:06:39.249Z', 'age': 3}  S37 T91-1181  U09 W46-5916
#
#                                       id  \
# 0  {'name': 'SIN', 'value': '762385482'}
#
#                                              picture nat
# 0  {'large': 'https://randomuser.me/api/portraits...  CA

# %%
pd.DataFrame(response.json()['results'])[['gender', 'email', 'phone']]
# Out:
#   gender                   email         phone
# 0   male  jeremy.roy@example.com  S37 T91-1181

# %%
api = 'https://api.apilayer.com/fixer/timeseries?start_date=2023-01-01&end_date=2023-06-10&base=USD&symbols=EUR,GBP&apikey=bRjFIndXHlCV7uhCiD6s26UUPE5VLOld'

# %%
response = requests.get(api)

# %%
response.json()
# Out:
# {'success': True,
#  'timeseries': True,
#  'start_date': '2023-01-01',
#  'end_date': '2023-06-10',
#  'base': 'USD',
#  'rates': {'2023-01-01': {'EUR': 0.934185, 'GBP': 0.826446},
#   '2023-01-02': {'EUR': 0.93656, 'GBP': 0.82904},
#   '2023-01-03': {'EUR': 0.94818, 'GBP': 0.835515},
#   '2023-01-04': {'EUR': 0.94265, 'GBP': 0.82931},
#   '2023-01-05': {'EUR': 0.950397, 'GBP': 0.839571},
#   '2023-01-06': {'EUR': 0.93775, 'GBP': 0.826925},
#   '2023-01-07': {'EUR': 0.93775, 'GBP': 0.826925},
#   '2023-01-08': {'EUR': 0.93844, 'GBP': 0.825395},
#   '2023-01-09': {'EUR': 0.93158, 'GBP': 0.82058},
#   '2023-01-10': {'EUR': 0.93122, 'GBP': 0.822785},
#   '2023-01-11': {'EUR': 0.929011, 'GBP': 0.822501},
#   '2023-01-12': {'EUR': 0.92083, 'GBP': 0.818475},
#   '2023-01-13': {'EUR': 0.92185, 'GBP': 0.817595},
#   '2023-01-14': {'EUR': 0.92185, 'GBP': 0.817595},
#   '2023-01-15': {'EUR': 0.92385, 'GBP': 0.817955},
#   '2023-01-16': {'EUR': 0.92338, 'GBP': 0.819215},
# ...

# %%
df1 = pd.DataFrame(response.json()['rates'])
df1
# Out:
#      2023-01-01  2023-01-02  2023-01-03  2023-01-04  2023-01-05  2023-01-06  \
# EUR    0.934185     0.93656    0.948180     0.94265    0.950397    0.937750
# GBP    0.826446     0.82904    0.835515     0.82931    0.839571    0.826925
#
#      2023-01-07  2023-01-08  2023-01-09  2023-01-10  ...  2023-06-01  \
# EUR    0.937750    0.938440     0.93158    0.931220  ...    0.929330
# GBP    0.826925    0.825395     0.82058    0.822785  ...    0.798375
#
#      2023-06-02  2023-06-03  2023-06-04  2023-06-05  2023-06-06  2023-06-07  \
# EUR    0.932350    0.932350    0.934802     0.93358     0.93478     0.93396
# GBP    0.803084    0.803181    0.804530     0.80434     0.80463     0.80361
#
#      2023-06-08  2023-06-09  2023-06-10
# EUR     0.92744    0.928904    0.928904
# GBP     0.79624    0.795171    0.795513
#
# [2 rows x 161 columns]
