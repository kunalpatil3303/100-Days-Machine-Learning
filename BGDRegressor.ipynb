# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import r2_score

# %%
df = pd.read_csv("/content/placement (2).csv")

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
X = df.drop(columns=["package"])
Y = df["package"]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
model = SGDRegressor(max_iter=100, learning_rate="constant", eta0=0.01, shuffle=False)

# %%
model.fit(X_train, Y_train)
# Out:
# SGDRegressor(learning_rate='constant', max_iter=100, shuffle=False)

# %%
X_test_prediction = model.predict(X_test)
X_test_r2_score = r2_score(Y_test, X_test_prediction)
print(X_test_r2_score)
# Out:
# 0.7088598902773267

# %%
plt.figure(figsize = (5,5))
sns.scatterplot(data = df, x = "cgpa", y = "package")
plt.plot(X_train, model.predict(X_train), color="red")
